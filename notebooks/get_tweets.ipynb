# %%
import pandas as pd

# %%
tweets = pd.read_csv("Tweets.csv")
tweets
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# ...                   ...               ...                           ...
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# ...

# %%
tweets[((tweets.negativereason == "Can't Tell") | (pd.isnull(tweets.negativereason))) & (tweets.airline_sentiment == "negative")].to_csv("unlabeled_negative_tweets.csv", index=False)

# %%
df = tweets[~((tweets.negativereason == "Can't Tell") | (pd.isnull(tweets.negativereason))) & (tweets.airline_sentiment == "negative")]

# %%
df
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 3      570301031407624196          negative                        1.0000
# 15     570282469121007616          negative                        0.6842
# 17     570276917301137409          negative                        1.0000
# 20     570265883513384960          negative                        0.6705
# 24     570256553502068736          negative                        1.0000
# ...                   ...               ...                           ...
# 14631  569588464896876545          negative                        1.0000
# 14633  569587705937600512          negative                        1.0000
# 14634  569587691626622976          negative                        0.6684
# 14636  569587371693355008          negative                        1.0000
# 14638  569587188687634433          negative                        1.0000
#
#                negativereason  negativereason_confidence         airline  \
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['negativereason'], test_size=0.2, stratify=df['negativereason'], random_state=42)

# %%
vectorizer = TfidfVectorizer()
X_train_vectors = vectorizer.fit_transform(X_train)
X_test_vectors = vectorizer.transform(X_test)

# %%
classifier = LinearSVC()
classifier.fit(X_train_vectors, y_train)
# Out:
# LinearSVC()

# %%
y_pred = classifier.predict(X_test_vectors)

# %%
report = classification_report(y_test, y_pred)
report
# Out:
# /Users/dylannewman/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dylannewman/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dylannewman/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
unlabeled_data = tweets[((tweets.negativereason == "Can't Tell") | (pd.isnull(tweets.negativereason))) & (tweets.airline_sentiment == "negative")]

# %%
new_vectors = vectorizer.transform(tweets["text"])

# %%
new_predictions = classifier.predict(new_vectors)
new_confidences = classifier.decision_function(new_vectors)

# %%
confidence_threshold = 0.5

# %%
tweets['predicted_category'] = [
    category if max_prob > confidence_threshold else None
    for category, probs in zip(new_predictions, new_confidences)
    for max_prob in [max(probs)]]

# %%
tweets
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# ...                   ...               ...                           ...
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# ...

# %%
unlabeled_data["negativereason"] = unlabeled_data["negativereason"].replace("Can't Tell", None)
# Out:
# /var/folders/xg/2jx4h1913bx28fptfgb7xjx00000gn/T/ipykernel_32523/3883863618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unlabeled_data["negativereason"] = unlabeled_data["negativereason"].replace("Can't Tell", None)

# %%
unlabeled_data["negativereason"] = unlabeled_data["negativereason"].fillna(unlabeled_data["predicted_category"])
# Out:
# /var/folders/xg/2jx4h1913bx28fptfgb7xjx00000gn/T/ipykernel_32523/2218809476.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unlabeled_data["negativereason"] = unlabeled_data["negativereason"].fillna(unlabeled_data["predicted_category"])

# %%
tweets["negativereason"] = tweets["negativereason"].replace("Can't Tell", None)

# %%
tweets["negativereason"] = tweets["negativereason"].fillna(tweets["predicted_category"])

# %%
tweets
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# ...                   ...               ...                           ...
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# ...

# %%
pd.DataFrame(pd.unique(tweets["tweet_location"])).to_csv("Test.csv", index=False)

# %%
from geopy.geocoders import GoogleV3
geolocator = GoogleV3(api_key='AIzaSyB3Nboc4DWnbDimlvfJ2TPs5P_LKUgvC70')  # Replace with your actual API key
def match_place_name(place_name):
    location = geolocator.geocode(place_name)  # Geocode the place name
    if location:
        return location.address
    else:
        return None

# Usage example
place_name = "Oakland"
match_place_name(place_name)
# Out:
# 'Oakland, CA, USA'

# %%
locations = pd.DataFrame(pd.unique(tweets["tweet_location"]))

# %%
tweets["tweet_id"]
# Out:
# 0        570306133677760513
# 1        570301130888122368
# 2        570301083672813571
# 3        570301031407624196
# 4        570300817074462722
#                 ...
# 14635    569587686496825344
# 14636    569587371693355008
# 14637    569587242672398336
# 14638    569587188687634433
# 14639    569587140490866689
# Name: tweet_id, Length: 14640, dtype: int64

# %%
locations = locations.rename(columns={0: "data"})

# %%
from tqdm import tqdm

# %%
tqdm.pandas()

# %%
names = locations["data"].progress_apply(match_place_name)
# Out:
# 100%|██████████| 3082/3082 [04:36<00:00, 11.15it/s]

# %%
names
# Out:
# 0                            None
# 1                            None
# 2          San Francisco, CA, USA
# 3            Los Angeles, CA, USA
# 4              San Diego, CA, USA
#                   ...
# 3077          Chelmsford, MA, USA
# 3078              Pueblo, CO, USA
# 3079            Columbus, OH, USA
# 3080    Milwaukee County, WI, USA
# 3081               Lagos, Nigeria
# Name: data, Length: 3082, dtype: object

# %%
locations["names"] = names

# %%
locations = locations.set_index("data")

# %%
locations = locations.drop_duplicates()

# %%
locations = locations.reset_index()

# %%
locations
# Out:
#                              data                      names
# 0                             NaN                       None
# 1                       Lets Play                       None
# 2                San Francisco CA     San Francisco, CA, USA
# 3                     Los Angeles       Los Angeles, CA, USA
# 4                       San Diego         San Diego, CA, USA
# ...                           ...                        ...
# 3077               Chelmsford, MA        Chelmsford, MA, USA
# 3078                   Pueblo, CO            Pueblo, CO, USA
# 3079            Columbus, OH, USA          Columbus, OH, USA
# 3080  Milwaukee County, Wisconsin  Milwaukee County, WI, USA
# 3081                Nigeria,lagos             Lagos, Nigeria
#
# [3082 rows x 2 columns]

# %%
tweets.merge(locations, how="left", left_on="tweet_location", right_on="data").to_csv("updated_data.csv", index=False)
